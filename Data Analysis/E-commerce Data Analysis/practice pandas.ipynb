# %% [markdown]
# ## 연습문제와 추가 문법으로 정리하는 pandas

# %% [markdown]
# #### 1. 00_Material(Uploaded)/00_data/olist_customers_dataset.csv 파일 pandas dataframe 으로 읽어오기 (데이터프레임 변수 이름은 doc 로 하기로 함)

# %%
import pandas as pd

doc = pd.read_csv('00_Material(Uploaded)/00_data/olist_customers_dataset.csv', encoding='utf-8-sig')

# %% [markdown]
# #### 2. 처음 5개 열 확인하기

# %%
doc.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# #### 3. 전체 record 수(행 수) 확인하기

# %%
doc.shape
# Out:
# (99441, 5)

# %% [markdown]
# #### 4. 전체 열의 수 확인하기

# %%
doc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %% [markdown]
# #### 5. 열의 이름 리스트로 가져오기

# %%
doc.columns
# Out:
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'],
#       dtype='object')

# %% [markdown]
# #### 6. 인덱스 확인하기

# %%
doc.index
# Out:
# RangeIndex(start=0, stop=99441, step=1)

# %% [markdown]
# #### 7. 다섯 숫자 요약(5 number summary) 확인하기

# %%
doc.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# ## 추가 문법 pandas.DataFrame.copy
# - 데이터프레임 중 일부를 선택 후, 조작하면 해당 데이터프레임도 변경
# - copy() 를 통해, 복사본을 만들어서 조작하여, 원본 데이터프레임은 보존 가능

# %% [markdown]
# #### 1. customer_zip_code_prefix, customer_city, customer_state 컬럼만 가져오기 (데이터프레임 변수 이름은 doc2로 하기로 함)

# %%
doc2 = doc[['customer_zip_code_prefix', 'customer_city', 'customer_state']]
doc2.head()
# Out:
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# #### 2. customer_city 가 sao paulo 인 레코드(행)만 가져오기 (데이터프레임 변수 이름은 doc3 으로 하기로 함)
# - 레코드(행) 수 확인도 해보기

# %%
doc3 = doc[doc['customer_city']=='sao paulo']
doc3.head()
# Out:
#                          customer_id                customer_unique_id  \
# 2   4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 6   fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 13  eabebad39a88bb6f5b52376faec28612  295c05e81917928d76245e842748184d
# 18  9b8ce803689b3562defaad4613ef426f  7f3a72e8f988c6e735ba118d54f47458
# 22  2938121a40a20953c43caa8c98787fcb  482441ea6a06b1f72fe9784756c0ea75
#
#     customer_zip_code_prefix customer_city customer_state
# 2                       1151     sao paulo             SP
# 6                       4534     sao paulo             SP
# 13                      5704     sao paulo             SP
# 18                      5416     sao paulo             SP
# 22                      5713     sao paulo             SP

# %%
doc3.shape
# Out:
# (15540, 5)

# %% [markdown]
# #### 3. customer_city 기준으로 행의 갯수를 확인해보세요 </font><br>
# - doc2에 value_counts() 를 써보세요 (value_counts() 는 Series 에만 적용 가능합니다.)

# %%
doc2['customer_city'].value_counts()
# Out:
# customer_city
# sao paulo            15540
# rio de janeiro        6882
# belo horizonte        2773
# brasilia              2131
# curitiba              1521
#                      ...
# bequimao                 1
# andarai                  1
# vargem grande            1
# curvelandia              1
# eugenio de castro        1
# Name: count, Length: 4119, dtype: int64

# %% [markdown]
# #### 4. doc 데이터프레임에서 customer_city 기준으로 행의 갯수를 확인해보세요 </font><br>
# 1. groupby 를 써서 customer_city 를 기준으로 행의 갯수를 count 하세요 (새로운 데이터프레임 변수 이름은 doc4로 하기로 함)<br>
# 2. doc4를 통해 customer_city 수도 확인해보세요 (데이터프레임 레코드(행) 수를 확인해보면 됩니다.)

# %%
doc4 = doc.groupby('customer_city').count()
doc4
# Out:
#                      customer_id  customer_unique_id  \
# customer_city
# abadia dos dourados            3                   3
# abadiania                      1                   1
# abaete                        12                  12
# abaetetuba                    11                  11
# abaiara                        2                   2
# ...                          ...                 ...
# xinguara                       9                   9
# xique-xique                    3                   3
# zacarias                       2                   2
# ze doca                        5                   5
# zortea                         2                   2
#
#                      customer_zip_code_prefix  customer_state
# customer_city
# abadia dos dourados                         3               3
# abadiania                                   1               1
# abaete                                     12              12
# ...

# %%
doc4.shape
# Out:
# (4119, 4)

# %% [markdown]
# ## 추가 문법 이해 (정렬, sort_values(), sort_index())
# 1. groupby(기준컬럼) 계산시, 기준컬럼은 인덱스로 설정이 되고, 해당 컬럼값을 기반으로 자동 정렬됨
# 2. 데이터프레임.sort_values(by=컬럼명, ascending=False)
#    - ascending=True: 오름차순 (디폴트)
#    - ascending=False: 내림차순
# 3. 시리즈.sort_values(ascending=True)
# 4. 데이터프레임/시리즈.sort_index(ascending=True): 인덱스 기준 정렬

# %% [markdown]
# #### 1. doc4에서 가장 레코드(행)의 수가 많은 customer_city 를 확인해보세요
# - doc4의 customer_id 를 기준으로 정렬하고, 가장 상단의 한 행만 출력하기

# %%
doc4['customer_id'].sort_values(ascending=False).head(n=1)
# Out:
# customer_city
# sao paulo    15540
# Name: customer_id, dtype: int64

# %% [markdown]
# #### 2. doc 에서 customer_city 를 인덱스로 만들고, 알파벳 순으로 인덱스를 정렬해보세요

# %%
doc.set_index('customer_city').sort_index()
# Out:
#                                           customer_id  \
# customer_city
# abadia dos dourados  a23e3f9a2b656b23b7e52075964b42cd
# abadia dos dourados  9e01f714a2b3b8962c222cf2b74c20dc
# abadia dos dourados  f11eb8f0b8b87510a93e3e1aa10b0ade
# abadiania            576d71ddb21b21763cfedce73b902180
# abaete               5e9e1ae42e02df93e9a591e86fd531a3
# ...                                               ...
# ze doca              1052e334b46dd1e9876946d6372a363e
# ze doca              d8b3ef6f73de33ae716e94d2478cc080
# ze doca              fc87e5c06780700952aa42998a22968f
# zortea               0a466d490a3c2fcc1e7177f4809ec7dd
# zortea               e046f992a304cc92e1b00d7fccdf1c42
#
#                                    customer_unique_id  \
# customer_city
# abadia dos dourados  afddf43a03a9941624ed42c0b2c17280
# abadia dos dourados  e1feae9083c4c2895ddf6dc80526a85d
# abadia dos dourados  64ee476500a01beb94df40f97a108c50
# abadiania            8d76b559181609308fcae630ea64cd61
# ...

# %% [markdown]
# #### 3.  doc2에서 customer_state 기준으로 행의 갯수를 확인해보세요</font><br>
# - doc2에 value_counts() 를 써보세요 (value_counts() 는 Series 에만 적용 가능합니다.)

# %%
doc2['customer_state'].value_counts()
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: count, dtype: int64

# %% [markdown]
# #### 4. doc2에서 customer_state 갯수를 확인해보세요

# %%
doc2['customer_state'].value_counts().shape
# Out:
# (27,)

# %% [markdown]
# #### 5. doc4에서 customer_city 갯수가 1000개 이상인 customer_city 갯수만 확인해보세요

# %%
doc4[doc4['customer_id'] >= 1000].shape
# Out:
# (9, 4)

# %% [markdown]
# #### 6. doc4에서 customer_city 갯수가 1000개 이상인 customer_city 이름을 확인해보세요

# %%
doc4[doc4['customer_id'] >= 1000].index
# Out:
# Index(['belo horizonte', 'brasilia', 'campinas', 'curitiba', 'guarulhos',
#        'porto alegre', 'rio de janeiro', 'salvador', 'sao paulo'],
#       dtype='object', name='customer_city')

# %% [markdown]
# #### 7. doc에서 결측치가 각 컬럼에 있는지 확인해보세요

# %%
doc.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %% [markdown]
# ## 추가 문법 이해 (to_list())
# - 시리즈.to_list()
#    - 컬럼값을 리스트 타입으로 리턴

# %% [markdown]
# #### 1. doc에서 중복된 customer_city 를 가진 행을 삭제한 후, customer_city 이름만 가져와보세요

# %%
doc.drop_duplicates(subset='customer_city', keep='last')['customer_city'].to_list()
# Out:
# ['vargem grande',
#  'agua fria de goias',
#  'taperuaba',
#  'cajueiro',
#  'canapi',
#  'itanhem',
#  'sao jose da coroa grande',
#  'sao jorge do ivai',
#  'nova laranjeiras',
#  'ivora',
#  'anaurilandia',
#  'pedro velho',
#  'glaura',
#  'sao miguel do aleixo',
#  'santo antonio do caiua',
#  'fernao',
#  'sao jose da tapera',
#  'cordeiros',
#  'ananas',
#  'godoy moreira',
#  'japi',
#  'barauna',
#  'sandolandia',
#  'inga',
#  'muritiba',
#  'desembargador otoni',
#  'ipiranga do norte',
#  'felipe guerra',
#  'rio formoso',
#  'igaratinga',
#  'cedro',
#  'sao joao da urtiga',
#  'bom jesus do querendo',
#  'formosa da serra negra',
#  'rainha do mar',
#  'banabuiu',
#  'chorrocho',
#  'cipo-guacu',
#  'itabaianinha',
#  'ibirapua',
#  'francisco santos',
#  'guimaraes',
#  'tapera',
#  'rio doce',
#  'tocos do moji',
#  'humberto de campos',
#  'riversul',
#  'lindolfo collor',
#  'santana do sobrado',
#  'central',
#  'nova independencia',
#  'sacra familia do tingua',
# ...

# %% [markdown]
# ## 추가 문법 이해 (pivot_table)
# - pivot_table(데이터프레임, values=None, index=None, aggfunc='mean', fill_value=None, margins=False, margins_name='All')
#   - values: 분석할 열 이름 리스트
#   - index: 인덱스로 들어갈 키 열
#   - aggfunc: 계산 방법, 간단히 {분석할열이름:계산방법} 으로 사전 형식으로 작성
#     - 주요 계산 방법: sum(합), mean(평균), median(중앙값), std(표준편차)
#   - fill_value: 결측치 대체 값
#   - margins: 모든 데이터의 총 분석 결과를 추가함 (예, 총 합)
#   - margins_name: 모든 데이터의 총 분석 결과의 이름

# %%
import pandas as pd

doc_covid = pd.read_csv('00_Material(Uploaded)/COVID-19-master/csse_covid_19_data/csse_covid_19_daily_reports/04-01-2020.csv', encoding='utf-8-sig')
doc_covid.head()
# Out:
#       FIPS     Admin2  Province_State Country_Region          Last_Update  \
# 0  45001.0  Abbeville  South Carolina             US  2020-04-01 21:58:49
# 1  22001.0     Acadia       Louisiana             US  2020-04-01 21:58:49
# 2  51001.0   Accomack        Virginia             US  2020-04-01 21:58:49
# 3  16001.0        Ada           Idaho             US  2020-04-01 21:58:49
# 4  19001.0      Adair            Iowa             US  2020-04-01 21:58:49
#
#          Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 0  34.223334  -82.461707          4       0          0       4
# 1  30.295065  -92.414197         47       1          0      46
# 2  37.767072  -75.632346          7       0          0       7
# 3  43.452658 -116.241552        195       3          0     192
# 4  41.330756  -94.471059          1       0          0       1
#
#                     Combined_Key
# 0  Abbeville, South Carolina, US
# 1          Acadia, Louisiana, US
# 2         Accomack, Virginia, US
# ...

# %% [markdown]
# #### 1. doc_covid 에서 중복된 Country_Region 각각에 대해 Confirmed 를 모두 더한 값을 컬럼으로 갖는 데이터프레임을 피봇테이블로 만드세요
# - 결측치는 0으로 만드세요

# %%
doc_covid2 = pd.pivot_table(doc_covid, 
                            index=['Country_Region'], 
                            values=['Confirmed'], 
                            aggfunc={'Confirmed': 'sum'}, 
                            fill_value=0)
doc_covid2
# Out:
#                       Confirmed
# Country_Region
# Afghanistan                 192
# Albania                     259
# Algeria                     847
# Andorra                     390
# Angola                        8
# ...                         ...
# Vietnam                     218
# West Bank and Gaza          134
# Winter Olympics 2022          0
# Zambia                       36
# Zimbabwe                      8
#
# [190 rows x 1 columns]

# %% [markdown]
# #### 2. doc_covid 에서 중복된 Country_Region 각각에 대해 Confirmed 를 모두 더한 값을 컬럼으로 갖는 데이터프레임을 피봇테이블로 만들고, 총 값을 'Total' 을 인덱스 값으로 하는 record 로 추가하세요
# - 결측치는 0으로 만드세요

# %%
doc_covid3 = pd.pivot_table(doc_covid, 
                            index=['Country_Region'], 
                            values=['Confirmed'], 
                            aggfunc={'Confirmed': 'sum'}, 
                            fill_value=0, 
                            margins=True, 
                            margins_name='Total')
doc_covid3
# Out:
#                       Confirmed
# Country_Region
# Afghanistan                 192
# Albania                     259
# Algeria                     847
# Andorra                     390
# Angola                        8
# ...                         ...
# West Bank and Gaza          134
# Winter Olympics 2022          0
# Zambia                       36
# Zimbabwe                      8
# Total                    938959
#
# [191 rows x 1 columns]
